# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
INPUT_FILENAME = 'example_parsed.csv'

df = pd.read_csv(INPUT_FILENAME)

# %%
df.head()
# Out:
#    Unnamed: 0          ts         device_id  type  subtype  to_ds  from_ds  \
# 0           0  1654884230  dev-6sdvl6005smx     0        5      0        0
# 1           1  1654884230  dev-6sdvl6005smx     0        5      0        0
# 2           2  1654884230  dev-6sdvl6005smx     0        4      0        0
# 3           3  1654884230  dev-6sdvl6005smx     0        5      0        0
# 4           4  1654884230  dev-6sdvl6005smx     0        5      0        0
#
#    flags  duration_id  sequence_ctrl  \
# 0      2           48          12320
# 1      2           48          12320
# 2      0            0           1104
# 3      2           48          12336
# 4      2           48          12336
#
#                                                addr1  \
# 0  "35421a8b4c93a349361c390c9e10f2a8faa30641dfa8f...
# 1  "35421a8b4c93a349361c390c9e10f2a8faa30641dfa8f...
# 2                                "FF:FF:FF:FF:FF:FF"
# 3  "35421a8b4c93a349361c390c9e10f2a8faa30641dfa8f...
# ...
